# %%
import pandas as pd
data1 = pd.read_csv("dropData.csv",index_col=0)
data1
# Out:
#        ta    ts  speed    kp  kd-kvfb  kd-kvff     ki  simul_settling_time  \
# 0    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 1    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 2    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 3    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# 4    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# ..    ...   ...    ...   ...      ...      ...    ...                  ...
# 537  20.0  20.0  100.0  65.0   2000.0   2000.0  0.014               0.1429
# 538  20.0  20.0  100.0  65.0   2000.0   2000.0  0.014               0.1429
# 539  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
# 540  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
# 541  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
#
#      trial_no  settling_time Unnamed: 10
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461 entries, 0 to 541
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ta                   456 non-null    float64
#  1   ts                   456 non-null    float64
#  2   speed                456 non-null    float64
#  3   kp                   456 non-null    float64
#  4   kd-kvfb              456 non-null    float64
#  5   kd-kvff              456 non-null    float64
#  6   ki                   456 non-null    float64
#  7   simul_settling_time  456 non-null    float64
#  8   trial_no             456 non-null    float64
#  9   settling_time        456 non-null    float64
#  10  Unnamed: 10          1 non-null      object
# dtypes: float64(10), object(1)
# memory usage: 43.2+ KB

# %%
t = data1[data1["settling_time"] != "발산"]
t
# Out:
#        ta    ts  speed    kp  kd-kvfb  kd-kvff     ki  simul_settling_time  \
# 0    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 1    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 2    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 3    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# 4    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# ..    ...   ...    ...   ...      ...      ...    ...                  ...
# 537  20.0  20.0  100.0  65.0   2000.0   2000.0  0.014               0.1429
# 538  20.0  20.0  100.0  65.0   2000.0   2000.0  0.014               0.1429
# 539  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
# 540  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
# 541  20.0  20.0  100.0  65.0   2000.0   2000.0  0.016               0.1413
#
#      trial_no settling_time Unnamed: 10
# ...

# %%
t["settling_time"] = t["settling_time"].astype("float64")
t
# Out:
# /var/folders/5v/ywkv8vl52zs0xz8k0x15y8fm0000gn/T/ipykernel_16539/3928863296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t["settling_time"] = t["settling_time"].astype("float64")
#        ta    ts  speed    kp  kd-kvfb  kd-kvff     ki  simul_settling_time  \
# 0    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 1    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 2    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 3    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# 4    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# ..    ...   ...    ...   ...      ...      ...    ...                  ...
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461 entries, 0 to 541
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ta                   456 non-null    float64
#  1   ts                   456 non-null    float64
#  2   speed                456 non-null    float64
#  3   kp                   456 non-null    float64
#  4   kd-kvfb              456 non-null    float64
#  5   kd-kvff              456 non-null    float64
#  6   ki                   456 non-null    float64
#  7   simul_settling_time  456 non-null    float64
#  8   trial_no             456 non-null    float64
#  9   settling_time        456 non-null    float64
#  10  Unnamed: 10          1 non-null      object
# dtypes: float64(10), object(1)
# memory usage: 43.2+ KB

# %%
t.to_csv("dropData.csv")

# %%
data2 = pd.read_excel("230807_data_label.xlsx")
data2
# Out:
#      ta  ts  speed   SLPKP  SLPKI  SLVKP  SLVKI  simul_settling_time  \
# 0    40  40    100    10.0      0     70    400                  NaN
# 1    40  40    100    10.0      0     70    400                  NaN
# 2    40  40    100    10.0      0     70    400                  NaN
# 3    40  40    100    20.0      0     70    400                  NaN
# 4    40  40    100    30.0      0     70    400                  NaN
# ..   ..  ..    ...     ...    ...    ...    ...                  ...
# 832  40  40    100  1910.0      0     70    400                  NaN
# 833  40  40    100  1910.0      0     70    400                  NaN
# 834  40  40    100  2010.0      0     70    400                  NaN
# 835  40  40    100  2010.0      0     70    400                  NaN
# 836  40  40    100  2010.0      0     70    400                  NaN
#
#      trial_no  settling_time  inposstability
# 0           1          0.279          0.2909
# 1           2          0.203          0.2729
# ...

# %%
col1 = data2["ta"].tolist()
col2 = data2["ts"].tolist()

# %%
pd.concat([data1,data2],axis=0)
# Out:
#        ta    ts  speed    kp  kd-kvfb  kd-kvff     ki  simul_settling_time  \
# 0    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 1    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 2    20.0  20.0  100.0  10.0   1400.0   1400.0  0.006               0.2304
# 3    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# 4    20.0  20.0  100.0  10.0   1400.0   1400.0  0.010               0.2685
# ..    ...   ...    ...   ...      ...      ...    ...                  ...
# 832  40.0  40.0  100.0   NaN      NaN      NaN    NaN                  NaN
# 833  40.0  40.0  100.0   NaN      NaN      NaN    NaN                  NaN
# 834  40.0  40.0  100.0   NaN      NaN      NaN    NaN                  NaN
# 835  40.0  40.0  100.0   NaN      NaN      NaN    NaN                  NaN
# 836  40.0  40.0  100.0   NaN      NaN      NaN    NaN                  NaN
#
# ...

# %%
import numpy as np
t = pd.DataFrame(np.array(col1).reshape(-1,1),columns=["a"])
t = pd.concat([t,pd.DataFrame(np.array(col2).reshape(-1,1),columns=["b"])],axis=1)
t
# Out:
#       a   b
# 0    40  40
# 1    40  40
# 2    40  40
# 3    40  40
# 4    40  40
# ..   ..  ..
# 832  40  40
# 833  40  40
# 834  40  40
# 835  40  40
# 836  40  40
#
# [837 rows x 2 columns]

# %%
"asdasdasd"[:-1]
# Out:
# 'asdasdas'
